# %%
import aiohttp
import asyncio
from json import loads

class KPU:
    def __init__(self) -> None: None

    async def fetch_json(self, session, url):
        async with session.get(url) as response:
            return await response.json()

    async def get_provinces(self) -> dict:
        ENDPOINT: str = 'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/0.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "provinces",
            "length": len(contents),
            "contents": contents
        }

    async def get_cities(self, prov_id: str) -> dict:
        ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/{prov_id}.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "city",
            "length": len(contents),
            "contents": contents
        }

    async def get_kec(self, prov_id: str, city_id: str) -> dict:
        ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/{prov_id}/{city_id}.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "kec",
            "length": len(contents),
            "contents": contents
        }

    async def get_kel(self, prov_id: str, city_id: str, kec_id: str) -> dict:
        ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/{prov_id}/{city_id}/{kec_id}.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "kec",
            "length": len(contents),
            "contents": contents
        }

    async def get_tps(self, prov_id: str, city_id: str, kec_id: str, kel_id: str) -> dict:
        ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/{prov_id}/{city_id}/{kec_id}/{kel_id}.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "kec",
            "length": len(contents),
            "contents": contents
        }

    async def get_tps_data(self, prov_id: str, city_id: str, kec_id: str, kel_id: str, tps_id: str) -> dict:
        ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/pemilu/hhcw/ppwp/{prov_id}/{city_id}/{kec_id}/{kel_id}/{tps_id}.json'
        async with aiohttp.ClientSession() as session:
            contents = await self.fetch_json(session, ENDPOINT)
        return {
            "name": "kec",
            "length": len(contents),
            "contents": contents
        }

# %%
import os
import csv

def write_csv(path: str = 'data.csv', data: dict = {_: 0}, fields: list = []) -> None:
    if not os.path.exists(path):
        with open(path, mode='w+', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=fields)
            writer.writeheader()
            writer.writerow(data)
    else:
        with open(path, mode='a', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=fields)
            writer.writerow(data)

def directory(path: str = './datasets') -> None:
  if not (os.path.exists(path) and os.path.isdir(path)): os.makedirs(path)

# %%
from datetime import datetime

async def main():
    kpu = KPU()
    directory(path = f'./datasets/')

    # Province
    provinces = await kpu.get_provinces()
    for _, v_province in enumerate(provinces.get('contents')):
        province_name = v_province['nama']
        province_code = v_province['kode']

        # City
        cities = await kpu.get_cities(prov_id=province_code)
        for _, v_city in enumerate(cities.get('contents')):
            city_name = v_city['nama']
            city_code = v_city['kode']

            # Kecamatan
            kecamatan = await kpu.get_kec(prov_id=province_code, city_id=city_code)
            for _, v_kecamatan in enumerate(kecamatan.get('contents')):
                kecamatan_name = v_kecamatan['nama']
                kecamatan_code = v_kecamatan['kode']

                # Kelurahan
                kelurahan = await kpu.get_kel(prov_id=province_code, city_id=city_code, kec_id=kecamatan_code)
                for _, v_kelurahan in enumerate(kelurahan.get('contents')):
                    kelurahan_name = v_kelurahan['nama']
                    kelurahan_code = v_kelurahan['kode']

                    # TPS
                    tps = await kpu.get_tps(prov_id=province_code, city_id=city_code,
                        kec_id=kecamatan_code, kel_id=kelurahan_code)

                    for _, v_tps in enumerate(tps.get('contents')):
                        tps_name = v_tps['nama']
                        tps_code = v_tps['kode']

                        tps_data = await kpu.get_tps_data(
                            prov_id=province_code,
                            city_id=city_code,
                            kec_id=kecamatan_code,
                            kel_id=kelurahan_code,
                            tps_id=tps_code
                        )

                        fields = [
                            'Province_ID',
                            'Province_Name',
                            'City_ID',
                            'City_Name',
                            'Kecamatan_ID',
                            'Kecamatan_Name',
                            'Kelurahan_ID',
                            'Kelurahan_Name',
                            'TPS_ID',
                            'TPS_Name',
                            'DPT',
                            'DPTb',
                            'DPK',
                            'Paslon_01',
                            'Paslon_02',
                            'Paslon_03',
                            'Valid_Vote',
                            'Invalid_Vote',
                            'Total_Vote',
                            'Status'
                        ]

                        administrative = tps_data['contents']['administrasi']
                        if administrative is None:
                          DPT, DPTb, DPK = 0, 0, 0
                          valid_vote, invalid_vote, total_vote = 0, 0, 0
                        else:
                          DPT  = administrative['pengguna_dpt_j']
                          DPTb = administrative['pengguna_dptb_j']
                          DPK  = administrative['pengguna_non_dpt_j']

                          valid_vote = administrative['pengguna_non_dpt_j']
                          invalid_vote = administrative['pengguna_non_dpt_j']
                          total_vote = administrative['pengguna_non_dpt_j']


                        chart = tps_data['contents']['chart']
                        if chart is None:
                            paslon_1, paslon_2, paslon_3 = 0, 0, 0
                            status = 'PROCESS'
                        else:
                            pres_data = sum([0 if v is None else v for v in chart.values()])
                            if pres_data == valid_vote and valid_vote + invalid_vote == total_vote:
                                paslon_1 = chart.get('100025', 0)
                                paslon_2 = chart.get('100026', 0)
                                paslon_3 = chart.get('100027', 0)
                                status = 'INVALID'
                            else:
                                paslon_1 = chart.get('100025', 0)
                                paslon_2 = chart.get('100026', 0)
                                paslon_3 = chart.get('100027', 0)
                                status = 'VALID'

                        data = {
                              'Province_ID': province_code,
                              'Province_Name': province_name,
                              'City_ID': city_code,
                              'City_Name': city_name,
                              'Kecamatan_ID': kecamatan_code,
                              'Kecamatan_Name': kecamatan_name,
                              'Kelurahan_ID': kelurahan_code,
                              'Kelurahan_Name': kelurahan_name,
                              'TPS_ID': tps_code,
                              'TPS_Name': tps_name,
                              'DPT': DPT,
                              'DPTb': DPTb,
                              'DPK': DPK,
                              'Paslon_01': paslon_1,
                              'Paslon_02': paslon_2,
                              'Paslon_03': paslon_3,
                              'Valid_Vote': valid_vote,
                              'Invalid_Vote': invalid_vote,
                              'Total_Vote': total_vote,
                              'Status': status
                          }

                        images = tps_data['contents']['images']
                        if images is not None:
                          for i, img in enumerate(images, start=1):
                            key = f'Image_C-Hasil_{i}'
                            fields.append(key)
                            data[key] = img

                        write_csv(
                          path = f'./datasets/{province_name}.csv',
                          fields = fields,
                          data = data
                        )

                        print(
                          f"[ {province_name}:{city_name}:{kecamatan_name}:{kelurahan_name}:{tps_name} ] {paslon_1} | {paslon_2} | {paslon_3}"
                        )

        # print(province_name)

# %%
if __name__ == '__main__' :
  await main()
# Out:
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:ALUE BAGOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:ALUE BAGOK:TPS 002 ] 149 | 14 | 1
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:ALUE BATEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:ALUE SUNDAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:ARONGAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:COT BULOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:COT BULOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:COT JURU MUDI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:COT KUMBANG:TPS 001 ] 145 | 35 | 1
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:DRIEN RAMPAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:DRIEN RAMPAK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:GUNONG PULO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:KARANG HAMPA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:KEUB:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:KEUB:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:KUBU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:KUBU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PANTE MUTIA:TPS 001 ] 181 | 32 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PANTON BAHAGIA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PANTON MAKMU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PEULANTEU LB:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PEULANTEU LB:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PEURIBU:TPS 001 ] 200 | 27 | 2
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PEURIBU:TPS 002 ] 180 | 28 | 1
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:PEURIBU:TPS 003 ] 162 | 38 | 2
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:RIMBA LANGGEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:RIMBA LANGGEH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SEUNEUBOK LHONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SEUNEUBOK TEUNGOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SEUNEUBOK TEUNGOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SIMPANG PEUT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SIMPANG PEUT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SIMPANG PEUT:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SUAK BIDOK:TPS 001 ] 173 | 22 | 3
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SUAK IE BEUSO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:SUAK KEUMUDEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:TEUPIN PERAHO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:TEUPIN PERAHO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:UJONG BEUSA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:UJONG SIMPANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:ARONGAN LAMBALEK:UJONG SIMPANG:TPS 002 ] 176 | 21 | 1
# [ ACEH:ACEH BARAT:BUBON:ALUE BAKONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:ALUE BAKONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:ALUE LHOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:BEURAWANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:BEURAWANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:BLANG SIBEUTONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:BLANG SIBEUTONG:TPS 002 ] 163 | 32 | 8
# [ ACEH:ACEH BARAT:BUBON:COT KEUMUNENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:COT LADA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:GUNONG PANAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:KUALA PLING:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:KUALA PLING:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:KUTA PADANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:KUTA PADANG:TPS 002 ] 212 | 33 | 1
# [ ACEH:ACEH BARAT:BUBON:LAYUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:LAYUNG:TPS 002 ] 105 | 45 | 5
# [ ACEH:ACEH BARAT:BUBON:LICEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:LICEH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:PEULANTEU SP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:PEULANTEU SP:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:RAMBONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:SEUMULENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:SEUNEUBOK TRAP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:SUAK PANGKAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:BUBON:ULEE BLANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 005 ] 144 | 51 | 4
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 007 ] 179 | 70 | 4
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:BLANG BEURANDANG:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 002 ] 162 | 80 | 6
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 005 ] 181 | 62 | 4
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 006 ] 176 | 66 | 4
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 011 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 013 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 014 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 015 ] 183 | 78 | 2
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:DRIEN RAMPAK:TPS 016 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 001 ] 196 | 42 | 4
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 005 ] 167 | 51 | 6
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPA:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPONG DARAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:GAMPONG DARAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KAMPUNG BELAKANG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 003 ] 166 | 52 | 12
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 005 ] 199 | 40 | 8
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 007 ] 189 | 44 | 5
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 008 ] 164 | 78 | 6
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 011 ] 179 | 57 | 6
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:KUTA PADANG:TPS 013 ] 168 | 53 | 3
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 004 ] 195 | 58 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 011 ] 210 | 46 | 3
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LAPANG:TPS 013 ] 190 | 50 | 9
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 008 ] 166 | 54 | 8
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:LEUHAN:TPS 011 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 003 ] 191 | 42 | 3
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PADANG SEURAHET:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PANGGONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PANGGONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PANGGONG:TPS 003 ] 141 | 91 | 13
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PASAR ACEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:PASIR:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 001 ] 175 | 54 | 5
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 004 ] 170 | 58 | 5
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 005 ] 155 | 60 | 7
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:RUNDENG:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 004 ] 195 | 63 | 2
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 011 ] 187 | 47 | 8
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 013 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SEUNEUBOK:TPS 014 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK INDRAPURI:TPS 001 ] 113 | 59 | 7
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK INDRAPURI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK NIE:TPS 001 ] 99 | 28 | 6
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RAYA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RAYA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RAYA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK RIBEE:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK SIGADENG:TPS 001 ] 160 | 40 | 2
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:SUAK SIGADENG:TPS 002 ] 159 | 36 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 006 ] 168 | 57 | 8
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 010 ] 121 | 76 | 60
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 011 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 013 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 014 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG BAROH:TPS 015 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 007 ] 165 | 72 | 3
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:JOHAN PAHLAWAN:UJONG KALAK:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE LHEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE LHOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE LHOK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE ON:TPS 001 ] 205 | 24 | 3
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE PEUDEUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE PEUDEUNG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE TAMPAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE TAMPAK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE TAMPAK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:ALUE TAMPAK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BABAH MEULABOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BEUREUGANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BEUREUGANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BEUREUGANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BLANG DALAM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BLANG GEUNANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:BLANG GEUNANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:DRIEN CALEUE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KAMPONG MESJID:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KAMPONG MESJID:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KEUDE ARON:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KEUDE ARON:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KEUDE TANJONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KEUDE TANJONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:KEURAMAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MAREK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MAREK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH BULOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH BULOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH GANTUNG:TPS 001 ] 114 | 13 | 4
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH GANTUNG:TPS 002 ] 117 | 19 | 1
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH RAMBOT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH RAMBOT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH RAYEUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNASAH RAYEUK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNUANG TANJONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:MEUNUANG TANJONG:TPS 002 ] 126 | 20 | 2
# [ ACEH:ACEH BARAT:KAWAY XVI:MUKO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG MANCANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG MANCANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG SIKABU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG SIKABU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG SIKABU:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PADANG SIKABU:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PALIMBUNGAN:TPS 001 ] 175 | 19 | 3
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI JAMBU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI JAMBU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI JEUMPA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI JEUMPA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI KUMBANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI KUMBANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI MEUGAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI MEUGAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI TEUNGOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PASI TEUNGOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PEUNIA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PEUNIA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUCOK PUNGKIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUNGKIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUNGKIE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUTIM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUTIM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:PUUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:SAWANG TEUBEI:TPS 001 ] 151 | 35 | 2
# [ ACEH:ACEH BARAT:KAWAY XVI:SAWANG TEUBEI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:SAWANG TEUBEI:TPS 003 ] 134 | 47 | 4
# [ ACEH:ACEH BARAT:KAWAY XVI:SIMPANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:SIMPANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:TANJONG BUNGONG:TPS 001 ] 225 | 45 | 2
# [ ACEH:ACEH BARAT:KAWAY XVI:TANJONG MEULABOH:TPS 001 ] 175 | 38 | 3
# [ ACEH:ACEH BARAT:KAWAY XVI:TELADAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:TEUPIN PANAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:TEUPIN PANAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:TUMPOK LADANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:KAWAY XVI:TUMPOK LADANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:BALEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:BALEE:TPS 002 ] 173 | 31 | 3
# [ ACEH:ACEH BARAT:MEUREUBO:BALEE:TPS 003 ] 132 | 67 | 14
# [ ACEH:ACEH BARAT:MEUREUBO:BUKIT JAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:BUKIT JAYA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:BULOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 001 ] 167 | 46 | 6
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 002 ] 186 | 36 | 3
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 003 ] 171 | 41 | 4
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:GUNONG KLENG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:LANGUNG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MESJID TUHA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MESJID TUHA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MESJID TUHA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 004 ] 164 | 71 | 10
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:MEUREUBO:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI ACEH BAROH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI ACEH BAROH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI ACEH TUNONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI ACEH TUNONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI MESJID:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI MESJID:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI MESJID:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI PINANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PASI PINANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA BARO RANTO P:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 011 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 901 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PAYA PEUNAGA:TPS 902 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA CUT UJONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA CUT UJONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA CUT UJONG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA CUT UJONG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA CUT UJONG:TPS 901 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA PASI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA RAYEUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA RAYEUK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA RAYEUK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PEUNAGA RAYEUK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PUCOK REUDEUP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:PULO TEUNGOH:TPS 001 ] 192 | 60 | 2
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG BARAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG BARAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG TIMUR:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG TIMUR:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG TIMUR:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANTO PANYANG TIMUR:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANUB DONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:RANUB DONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:REUDEUP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:SUMBER BATU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG DRIEN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG DRIEN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG DRIEN:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG DRIEN:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANJONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANJONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANJONG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANJONG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANOH DARAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANOH DARAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANOH DARAT:TPS 003 ] 210 | 44 | 3
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANOH DARAT:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:MEUREUBO:UJONG TANOH DARAT:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:ALUE KEUMANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:BABAH ISEUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:BABAH KRUENG TEP LEP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:BABAH LUENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:BERDIKARI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:CANGGAI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:GUNONG TAROK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:JAMBAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:KEUDE SUAK AWE:TPS 001 ] 107 | 73 | 3
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:KEUTAMBANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:KEUTAMBANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:KREUNG BEUKAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LANGO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LANGO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LAWET:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LAWET:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LHOK GUCI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LHOK GUCI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LHOK SARI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:LHOK SARI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:MANJENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:MANJENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:MEUNUANG KINCO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:MEUNUANG KINCO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:PANTE CEUREMEN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:PANTE CEUREMEN:TPS 002 ] 220 | 44 | 1
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:PULO TEUNGOH MANJENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:PULO TEUNGOH MANJENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SAWANG RAMBOT:TPS 001 ] 100 | 49 | 4
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SAWANG RAMBOT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SEUMANTOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SEUMANTOK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SEUMANTOK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SEUMARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SEUMARA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SIKUNDO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SUAK AWE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:SUAK AWE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:TEGAL SARI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTE CEUREUMEN:TEGAL SARI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:ANTONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:BABAH KRUENG MANGGIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:BARO PAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:BLANG BALEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:BLANG TEUNGOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:COT MANGGIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:GAMPONG BARO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:GAMPONG BARO:TPS 002 ] 103 | 35 | 3
# [ ACEH:ACEH BARAT:PANTON REU:GUNONG MATA IE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:KUALA MANYEU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:LEK-LEK:TPS 001 ] 137 | 23 | 1
# [ ACEH:ACEH BARAT:PANTON REU:LEK-LEK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:MANGGIE:TPS 001 ] 221 | 31 | 1
# [ ACEH:ACEH BARAT:PANTON REU:MANGGIE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:MEUTULANG:TPS 001 ] 193 | 34 | 3
# [ ACEH:ACEH BARAT:PANTON REU:MEUTULANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:MEUTULANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:MUGO CUT:TPS 001 ] 460 | 96 | 5
# [ ACEH:ACEH BARAT:PANTON REU:MUGO RAYEUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:MUGO RAYEUK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:PAYA BARO MEUKO:TPS 001 ] 72 | 53 | 3
# [ ACEH:ACEH BARAT:PANTON REU:SIBINTANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:TAMPING:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:TUWI BUYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:PANTON REU:UJONG RAJA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:ALUE RAYA:TPS 001 ] 153 | 18 | 3
# [ ACEH:ACEH BARAT:SAMATIGA:ALUE RAYA:TPS 002 ] 135 | 45 | 1
# [ ACEH:ACEH BARAT:SAMATIGA:COT AMUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT DARAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT DARAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT DARAT:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT LAMPISE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT MESJID:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT PLUH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT PLUH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT SEULAMAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT SEULAMAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT SEUMEUREUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT SEUMEUREUNG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:COT SEUMEUREUNG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:DEUAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:DEUAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:GAMPONG COT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:GAMPONG COT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:GAMPONG LADANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:GAMPONG TEUNGOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:GAMPONG TEUNGOH:TPS 002 ] 155 | 41 | 8
# [ ACEH:ACEH BARAT:SAMATIGA:KEUREUSENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:KEUREUSENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:KRUENG TINGGAI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:KRUENG TINGGAI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:KUALA BUBON:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:LEUBOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:LEUKEUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:LEUKEUN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:LHOK BUBON:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:MESJID BARO:TPS 001 ] 123 | 18 | 2
# [ ACEH:ACEH BARAT:SAMATIGA:MESJID BARO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PANGE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PAYA LUMPAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PAYA LUMPAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PAYA LUMPAT:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PINEM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PINEM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PUCOK LUENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:PUCOK LUENG:TPS 002 ] 122 | 37 | 5
# [ ACEH:ACEH BARAT:SAMATIGA:RANGKILEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:REUSAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:REUSAK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK GEUDEUBANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK PANDAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK PANDAN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK PANTE BREUH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK PANTE BREUH:TPS 002 ] 177 | 24 | 1
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK SEUKE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK SEUKE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK SEUMASEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK TIMAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK TIMAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:SUAK TIMAH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SAMATIGA:UJONG NGA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:DRIEN SIBAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:GASEU:TPS 001 ] 149 | 12 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:GEUDONG:TPS 001 ] 228 | 71 | 6
# [ ACEH:ACEH BARAT:SUNGAI MAS:GLENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:GLENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:GUNONG BULOH:TPS 001 ] 60 | 7 | 1
# [ ACEH:ACEH BARAT:SUNGAI MAS:KAJEUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:KAJEUNG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:LANCONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:LUBOK BEUTONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:LUENG BARO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:PUNGKIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:RAMITIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:SAKUY:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:SARAH PERLAK:TPS 001 ] 68 | 65 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:SIPOT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:TANOH MIRAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:TUNGKOP:TPS 001 ] 63 | 111 | 5
# [ ACEH:ACEH BARAT:SUNGAI MAS:TUNGKOP:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:TUTUT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:SUNGAI MAS:TUWI SAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:ALUE BLANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:ALUE PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:ALUE SIKAYA:TPS 001 ] 256 | 22 | 0
# [ ACEH:ACEH BARAT:WOYLA:ALUE SUNDAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:ARON BAROH:TPS 001 ] 113 | 32 | 0
# [ ACEH:ACEH BARAT:WOYLA:ARON TUNONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:BAKAT:TPS 001 ] 140 | 50 | 1
# [ ACEH:ACEH BARAT:WOYLA:BAKAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:BLANG MEE:TPS 001 ] 161 | 15 | 0
# [ ACEH:ACEH BARAT:WOYLA:BLANG MEE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:COT KEUMUDE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:COT LAGAN BUBON:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:COT LAGAN BUBON:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:COT MURONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:COT SITUAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:DARUL HUDA:TPS 001 ] 103 | 43 | 4
# [ ACEH:ACEH BARAT:WOYLA:DRIEN MANGKO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:GEUMPA RAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:GLEE SIBLAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:GUNONG HAMPA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:GUNONG RAMBONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:IE ITAM BAROH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:IE ITAM BAROH:TPS 002 ] 122 | 24 | 4
# [ ACEH:ACEH BARAT:WOYLA:IE ITAM TUNONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:JAWA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:JAWI:TPS 001 ] 106 | 105 | 2
# [ ACEH:ACEH BARAT:WOYLA:KEULEUMBAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:KUALA BHEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:KUALA BHEE:TPS 002 ] 154 | 39 | 4
# [ ACEH:ACEH BARAT:WOYLA:KUALA BHEE:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG BULOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG BULOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG JAWA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG TANOH THO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG TANOH THO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:LUENG TEUNGKU YAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PADANG JAWA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PADANG JAWA:TPS 002 ] 125 | 26 | 3
# [ ACEH:ACEH BARAT:WOYLA:PANTON:TPS 001 ] 29 | 117 | 0
# [ ACEH:ACEH BARAT:WOYLA:PASI ACEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PASI ACEH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PASI ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PASI BIRAH:TPS 001 ] 67 | 61 | 3
# [ ACEH:ACEH BARAT:WOYLA:PASI LUNAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PASI PANDAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PAYA DUA:TPS 001 ] 116 | 39 | 2
# [ ACEH:ACEH BARAT:WOYLA:PAYA DUA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PAYA LUAH:TPS 001 ] 62 | 85 | 7
# [ ACEH:ACEH BARAT:WOYLA:PAYA LUAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:PULO IE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:RANTO PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:SEUMANTOK:TPS 001 ] 98 | 86 | 2
# [ ACEH:ACEH BARAT:WOYLA:SUAK TRIENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:TEUMAROM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA:TINGKEUM PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:ALUE KEUMUNING:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:ALUE KEUMUNING:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:ALUE LEUHOB:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:ALUE PERMAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:BLANG COT MAMEH:TPS 001 ] 70 | 79 | 2
# [ ACEH:ACEH BARAT:WOYLA BARAT:BLANG COT RUBEK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:BLANG LUAH LM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:BLANG LUAH LM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:COT LAGAN LM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:COT LAGAN LM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:COT RAMBONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:IE SAYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:KARAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:KARAK:TPS 002 ] 176 | 45 | 2
# [ ACEH:ACEH BARAT:WOYLA BARAT:KULAM KAJU:TPS 001 ] 106 | 51 | 1
# [ ACEH:ACEH BARAT:WOYLA BARAT:LEUBOK PASI ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:LHOK MALEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:LUENG BARO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:MON PASONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:MON PASONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:NAPAI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:NAPAI:TPS 002 ] 134 | 13 | 3
# [ ACEH:ACEH BARAT:WOYLA BARAT:PASI JEUT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:PASI MALEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:PASI MALI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:PASI MALI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:PASI PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:PEULEUKUENG:TPS 001 ] 75 | 59 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:SIMPANG TEUMAROM:TPS 001 ] 81 | 23 | 3
# [ ACEH:ACEH BARAT:WOYLA BARAT:ULEE PASI ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA BARAT:ULEE PULO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE BILIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE EUMPEUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE KUYUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE KUYUN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE MEUGANDA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:ALUE SEURALEN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:BLANG DALAM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:BLANG LUAH KB:TPS 001 ] 61 | 64 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:BLANG MAKMUE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:BUKIT MEUGAJAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:COT PUNTI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:GAMPONG BARO KB:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:GAMPONG BARO WT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:GUNONG PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:KUBU CAPANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:LUBUK PANYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:PASI ARA WT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:PASI JANENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:PASI JANENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:PAYA BARO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:PAYA MEUGENDRANG:TPS 001 ] 82 | 57 | 2
# [ ACEH:ACEH BARAT:WOYLA TIMUR:RAMBONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:RAMBONG PINTO:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:SEUNEUBOK DALAM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:SEURADEUK:TPS 001 ] 148 | 74 | 1
# [ ACEH:ACEH BARAT:WOYLA TIMUR:TANGKEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:TEUMIKET RANOM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT:WOYLA TIMUR:TUWI EUMPEUK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE DAWAH:TPS 001 ] 181 | 28 | 3
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE DAWAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE JEUREJAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE JEUREJAK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE JEUREJAK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE JEUREJAK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE PEUNAWA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE PEUNAWA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:ALUE PEUNAWA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG DALAM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG DALAM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG DALAM:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG DALAM:TPS 004 ] 208 | 22 | 1
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG DALAM:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG RAJA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG RAJA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG RAJA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:BLANG RAJA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:COT SEUMANTOK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:COT SEUMANTOK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:COT SEUMANTOK:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:COT SEUMANTOK:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:GUNUNG SAMARINDA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:GUNUNG SAMARINDA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:GUNUNG SAMARINDA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:GUNUNG SAMARINDA:TPS 004 ] 176 | 45 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:GUNUNG SAMARINDA:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:IE MIRAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:IE MIRAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:IE MIRAH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:IE MIRAH:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:IE MIRAH:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:LHOK GAYO:TPS 001 ] 174 | 29 | 3
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:LHOK GAYO:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:LHOK GAYO:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE CERMIN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE CERMIN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE CERMIN:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 007 ] 184 | 49 | 2
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:PANTE RAKYAT:TPS 008 ] 186 | 53 | 4
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:RUKOEN DAME:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:RUKOEN DAME:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:RUKOEN DAME:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:RUKOEN DAME:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:SIMPANG GADENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:SIMPANG GADENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:SIMPANG GADENG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:TELADAN JAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:TELADAN JAYA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:TELADAN JAYA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BABAH ROT:TELADAN JAYA:TPS 004 ] 169 | 15 | 2
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:ALUE MANGGOTA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:ALUE MANGGOTA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:ALUE MANGGOTA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BABAH LHUNG:TPS 001 ] 205 | 38 | 1
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BABAH LHUNG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BABAH LHUNG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BABAH LHUNG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BAHARU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BAHARU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:BAHARU:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:COT JEURAT:TPS 001 ] 184 | 28 | 1
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:COT JEURAT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GEULUMPANG PAYONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GEULUMPANG PAYONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GEULUMPANG PAYONG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GEULUMPANG PAYONG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GEULUMPANG PAYONG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GUDANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GUDANG:TPS 002 ] 143 | 49 | 2
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GUHANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:GUHANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE PAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE PAYA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE PAYA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 003 ] 151 | 56 | 11
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KEUDE SIBLAH:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA BAHAGIA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA BAHAGIA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TINGGI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TINGGI:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TINGGI:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TINGGI:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TUHA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TUHA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TUHA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:KUTA TUHA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LAM KUTA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LAM KUTA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LHUNG ASAN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LHUNG ASAN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LHUNG TAROK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:LHUNG TAROK:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MATA IE:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:MEUDANG ARA:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:PANTON RAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:PASAR BLANGPIDIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:PASAR BLANGPIDIE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:SEUNALOH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:SEUNALOH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:BLANGPIDIE:SEUNALOH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE RAMBOT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE RAMBOT:TPS 002 ] 166 | 27 | 4
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SEULASEH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SEULASEH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SEULASEH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SUNGAI PINANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SUNGAI PINANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BARAT DAYA:JEUMPA:ALUE SUNGAI PINANG:TPS 003 ] 0 | 0 | 0
# ...
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 003 ] 217 | 12 | 0
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 004 ] 186 | 48 | 5
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 005 ] 162 | 47 | 9
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 006 ] 177 | 43 | 1
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 007 ] 186 | 36 | 1
# [ ACEH:ACEH BESAR:BAITUSSALAM:MIRUK LAM REUDEP:TPS 008 ] 723 | 727 | 4
# [ ACEH:ACEH BESAR:BLANG BINTANG:BUENG PAGEU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:BUENG PAGEU:TPS 002 ] 145 | 66 | 2
# [ ACEH:ACEH BESAR:BLANG BINTANG:BUENG SIDOM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT BAGIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT BAGIE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT GEUNDREUT:TPS 001 ] 186 | 16 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT GEUNDREUT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT HOHO:TPS 001 ] 71 | 13 | 1
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT JAMBO:TPS 001 ] 245 | 26 | 1
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT KARIENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT KARIENG:TPS 002 ] 168 | 35 | 4
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT LEUOT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MADHI:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MALEM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MALEM:TPS 002 ] 150 | 24 | 1
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MANCANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MEULANGEUN:TPS 001 ] 149 | 16 | 4
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT MON RAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT NAMBAK:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT PUKLAT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT PUKLAT:TPS 002 ] 135 | 8 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT RUMPUN:TPS 001 ] 198 | 24 | 2
# [ ACEH:ACEH BESAR:BLANG BINTANG:COT SAYUN:TPS 001 ] 90 | 22 | 4
# [ ACEH:ACEH BESAR:BLANG BINTANG:DATA MAKMUR:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:DATA MAKMUR:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:EMPEE BATA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:EMPEE BATA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:KAMPUNG BLANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:KAMPUNG BLANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:KAMPUNG BLANG:TPS 003 ] 150 | 38 | 2
# [ ACEH:ACEH BESAR:BLANG BINTANG:KAYEE KUNYET:TPS 001 ] 204 | 24 | 4
# [ ACEH:ACEH BESAR:BLANG BINTANG:KAYEE KUNYET:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:LAM SIEM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:LAM SIEM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:LAMME:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:LAMME:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:MEULAYO:TPS 001 ] 201 | 21 | 2
# [ ACEH:ACEH BESAR:BLANG BINTANG:PAYA UE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:BLANG BINTANG:PAYA UE:TPS 002 ] 110 | 18 | 9
# [ ACEH:ACEH BESAR:BLANG BINTANG:TEUPIN BATEE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:BAYU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:BAYU:TPS 002 ] 210 | 25 | 4
# [ ACEH:ACEH BESAR:DARUL IMARAH:BAYU:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:BAYU:TPS 004 ] 194 | 21 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:BAYU:TPS 005 ] 197 | 26 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:DAROY KAMEU:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:DAROY KAMEU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:DEUNONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:DEUNONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:DEUNONG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 003 ] 180 | 40 | 9
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 005 ] 185 | 37 | 5
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 006 ] 170 | 39 | 11
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 011 ] 192 | 39 | 8
# [ ACEH:ACEH BESAR:DARUL IMARAH:GAROT:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GEUNDRIENG:TPS 001 ] 206 | 39 | 6
# [ ACEH:ACEH BESAR:DARUL IMARAH:GEUNDRIENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 004 ] 189 | 31 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 008 ] 196 | 38 | 7
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 011 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 013 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 014 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:GUE GAJAH:TPS 015 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:JEUMPET AJUN:TPS 006 ] 199 | 30 | 5
# [ ACEH:ACEH BESAR:DARUL IMARAH:KANDANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:KUTA KARANG:TPS 001 ] 234 | 11 | 5
# [ ACEH:ACEH BESAR:DARUL IMARAH:KUTA KARANG:TPS 002 ] 243 | 17 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAGANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAGANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 001 ] 184 | 37 | 7
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 003 ] 162 | 49 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 009 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 010 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 011 ] 170 | 23 | 6
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 012 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BHEU:TPS 013 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG MAYANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG MAYANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG MAYANG:TPS 003 ] 153 | 29 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG TRIENG:TPS 001 ] 160 | 18 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG TRIENG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAM BLANG TRIENG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMCOT:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMKAWE:TPS 001 ] 262 | 10 | 3
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMKAWE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 001 ] 191 | 30 | 4
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 004 ] 181 | 38 | 4
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 005 ] 183 | 23 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPASI ENGKING:TPS 006 ] 161 | 26 | 3
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEUN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT GAMPONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT GAMPONG:TPS 002 ] 210 | 30 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT GAMPONG:TPS 003 ] 187 | 29 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 002 ] 210 | 19 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 005 ] 162 | 42 | 6
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMPEUNEURUT UJONG BLANG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 002 ] 176 | 29 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 004 ] 199 | 18 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMREUNG:TPS 007 ] 189 | 22 | 3
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMSIDAYA:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMSIDAYA:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMSIDAYA:TPS 003 ] 218 | 13 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMSITEH:TPS 001 ] 157 | 19 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMSITEH:TPS 002 ] 155 | 23 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMTHEUN:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMTHEUN:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LAMTHEUN:TPS 003 ] 161 | 19 | 3
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU GEU:TPS 001 ] 125 | 14 | 6
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU GEU:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU UE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU UE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU UE:TPS 003 ] 145 | 58 | 6
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU UE:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LEU UE:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LHEU BLANG:TPS 001 ] 174 | 27 | 5
# [ ACEH:ACEH BESAR:DARUL IMARAH:LHEU BLANG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:LHEU BLANG:TPS 003 ] 176 | 20 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:PASHEU BEUTONG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PASHEU BEUTONG:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PASHEU BEUTONG:TPS 003 ] 211 | 38 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:PASHEU BEUTONG:TPS 004 ] 174 | 32 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PAYAROH:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PAYAROH:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PAYAROH:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 006 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 007 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:PUNIE:TPS 008 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:TINGKUEM:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:TINGKUEM:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:TINGKUEM:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:TINGKUEM:TPS 004 ] 177 | 13 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE LUENG:TPS 001 ] 160 | 17 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE LUENG:TPS 002 ] 168 | 15 | 3
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE LUENG:TPS 003 ] 153 | 31 | 2
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE TUY:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE TUY:TPS 002 ] 177 | 38 | 1
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE TUY:TPS 003 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE TUY:TPS 004 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL IMARAH:ULEE TUY:TPS 005 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:BILUY:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:BILUY:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:BLANG KIREE:TPS 001 ] 193 | 21 | 4
# [ ACEH:ACEH BESAR:DARUL KAMAL:BLANG KIREE:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:EMPEE TRIENG:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:EMPEE TRIENG:TPS 002 ] 153 | 9 | 3
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBARO BILUY:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBARO BILUY:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBATEE:TPS 001 ] 180 | 17 | 2
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBLEUT:TPS 001 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBLEUT:TPS 002 ] 0 | 0 | 0
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMBLEUT:TPS 003 ] 178 | 25 | 1
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMKUNYET:TPS 001 ] 204 | 9 | 3
# [ ACEH:ACEH BESAR:DARUL KAMAL:LAMKUNYET:TPS 002 ] 201 | 15 | 0
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-6-602d4f2e61d7> in <cell line: 1>()
#       1 if __name__ == '__main__' :
# ----> 2   await main()
#
# <ipython-input-5-c4532d8d085e> in main()
#      32
#      33                     # TPS
# ---> 34                     tps = await kpu.get_tps(prov_id=province_code, city_id=city_code,
#      35                         kec_id=kecamatan_code, kel_id=kelurahan_code)
#      36
#
# <ipython-input-1-eaff8fa5229a> in get_tps(self, prov_id, city_id, kec_id, kel_id)
#      54         ENDPOINT: str = f'https://sirekap-obj-data.kpu.go.id/wilayah/pemilu/ppwp/{prov_id}/{city_id}/{kec_id}/{kel_id}.json'
#      55         async with aiohttp.ClientSession() as session:
# ---> 56             contents = await self.fetch_json(session, ENDPOINT)
#      57         return {
#      58             "name": "kec",
#
# <ipython-input-1-eaff8fa5229a> in fetch_json(self, session, url)
#       8
#       9     async def fetch_json(self, session, url):
# ---> 10         async with session.get(url) as response:
#      11             return await response.json()
#      12
#
# /usr/local/lib/python3.10/dist-packages/aiohttp/client.py in __aenter__(self)
#    1192
#    1193     async def __aenter__(self) -> _RetType:
# -> 1194         self._resp = await self._coro
#    1195         return self._resp
#    1196
#
# /usr/local/lib/python3.10/dist-packages/aiohttp/client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     603                             resp = await req.send(conn)
#     604                             try:
# --> 605                                 await resp.start(conn)
#     606                             except BaseException:
#     607                                 resp.close()
#
# /usr/local/lib/python3.10/dist-packages/aiohttp/client_reqrep.py in start(self, connection)
#     964                 try:
#     965                     protocol = self._protocol
# --> 966                     message, payload = await protocol.read()  # type: ignore[union-attr]
#     967                 except http.HttpProcessingError as exc:
#     968                     raise ClientResponseError(
#
# /usr/local/lib/python3.10/dist-packages/aiohttp/streams.py in read(self)
#     620             self._waiter = self._loop.create_future()
#     621             try:
# --> 622                 await self._waiter
#     623             except (asyncio.CancelledError, asyncio.TimeoutError):
#     624                 self._waiter = None
#
# CancelledError:
